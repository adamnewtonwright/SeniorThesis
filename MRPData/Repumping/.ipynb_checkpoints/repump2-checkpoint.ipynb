# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# With repumper pulsed and same polarization as main laser

# %% [markdown]
# # High Intensity of 1.5 mW

# %% [markdown]
# ## Continuous

# %% [markdown]
# ### Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 1.4

angles = np.array([0,90])
dv =     np.array([62.4,55.2])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 10%

# %%
#mag field current = .12 A
repump = 0.14
master = 1.4

dv =     np.array([66,60])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repumper', fontsize =18)
plt.legend()

# %% [markdown]
# ### Repump 20%

# %%
#mag field current = .12 A
repump = 0.28
master = 1.4

dv =     np.array([70.8,65.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# # Pulsed

# %% [markdown]
# ## Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 1.40

dv =     np.array([50.0,48])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
plt.ylim(.85,1.01)
#plt.title('0% Repump Scaled')
plt.legend()

# %% [markdown]
# ## Repump 10%

# %%
#mag field current = .12 A
repump = 0.14
master = 1.4

dv =     np.array([55.2,53.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()

# %% [markdown]
# ## Repump 20%

# %%
#mag field current = .12 A
repump = 0.28
master = 1.4

dv =     np.array([57.2,56.8])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
plt.ylabel('Fluorescence (dV)')
plt.savefig('fluorescencehigh2.pdf')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()
plt.savefig('20scaledhigh2.pdf')

# %%
plt.show()

# %% [markdown]
# # High Intensity of 1.5 mW, round 2

# %% [markdown]
# ## Continuous

# %% [markdown]
# ### Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 1.4

angles = np.array([0,90])
dv =     np.array([61.2,56])

plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 10%

# %%
#mag field current = .12 A
repump = 0.14
master = 1.4

dv =     np.array([68.8,62.8])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repumper', fontsize =18)
plt.legend()

# %% [markdown]
# ### Repump 20%

# %%
#mag field current = .12 A
repump = 0.28
master = 1.4

dv =     np.array([73.2,67.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# # Pulsed

# %% [markdown]
# ## Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 1.40

dv =     np.array([50.4,47.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
plt.ylim(.85,1.01)
#plt.title('0% Repump Scaled')
plt.legend()

# %% [markdown]
# ## Repump 10%

# %%
#mag field current = .12 A
repump = 0.14
master = 1.4

dv =     np.array([53.6,52.8])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()

# %% [markdown]
# ## Repump 20%

# %%
#mag field current = .12 A
repump = 0.28
master = 1.4

dv =     np.array([55.6,55.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
plt.ylabel('Fluorescence (dV)')
plt.savefig('20fluorescencehigh21.pdf')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()
plt.savefig('20scaledhigh21.pdf')

# %%
plt.show()

# %% [markdown]
# # Low Intensity of 0.5 mW

# %% [markdown]
# ## Continuous

# %% [markdown]
# ### Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 0.5

angles = np.array([0,90])
dv =     np.array([30,26.6])

plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 10%

# %%
#mag field current = .12 A
repump = 0.05
master = 0.5

dv =     np.array([33.2,29.8])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repumper', fontsize =18)
plt.legend()

# %% [markdown]
# ### Repump 20%

# %%
#mag field current = .12 A
repump = 0.1
master = 0.5

dv =     np.array([33.6,30.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# # Pulsed

# %% [markdown]
# ## Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 0.5

dv =     np.array([24.8,24])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
plt.ylim(.85,1.01)
#plt.title('0% Repump Scaled')
plt.legend()

# %% [markdown]
# ## Repump 10%

# %%
#mag field current = .12 A
repump = 0.05
master = 0.5

dv =     np.array([26.2,26.0])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()

# %% [markdown]
# ## Repump 20%

# %%
#mag field current = .12 A
repump = 0.1
master = 0.5

dv =     np.array([26.4,26.4])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
plt.ylabel('Fluorescence (dV)')
plt.savefig('20fluorescencelow21.pdf')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()
plt.savefig('20scaledlow21.pdf')

# %%
plt.show()
