# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# With repumper pulsed and same polarization as main laser

# %% [markdown]
# # Low Intensity of 0.4 mW

# %% [markdown]
# ## Continuous

# %% [markdown]
# ### Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 0.4

angles = np.array([0,90])
dv =     np.array([19.4,17.6])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '0% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 5%

# %%
#mag field current = .12 A
repump = 0.05
master = 1.0

angles = np.array([0,90])
dv =     np.array([52,47.76])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '5% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '5% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 10%

# %%
#mag field current = .12 A
repump = 0.10
master = 1.0

dv =     np.array([53.2,49.2])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '10% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repumper', fontsize =18)
plt.legend()

# %% [markdown]
# ### Repump 15%

# %%
#mag field current = .12 A
repump = 0.15
master = 1.0

angles = np.array([0,90])
dv =     np.array([55.6,51.6])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '15% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '15% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 20%

# %%
#mag field current = .12 A
repump = 0.2
master = 1.0

dv =     np.array([56.4,52])

plt.figure('0repump')
plt.plot(angles,dv,'.--', label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '20% Repumper Continuous')
plt.grid(True)
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 25%

# %%
#mag field current = .12 A
repump = 0.25
master = 1.0

angles = np.array([0,90])
dv =     np.array([57.2,53.2])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '25% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '25% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 30%

# %%
#mag field current = .12 A
repump = 0.30
master = 1.0

angles = np.array([0,90])
dv =     np.array([57.2,52.8])


plt.figure('0repump')
plt.plot(angles,dv,'.--',label = '30% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.--',markersize = 10.0, label = '30% Repumper Continuous')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()/

# %% [markdown]
# # Pulsed

# %% [markdown]
# ### Repump 0%

# %%
#mag field current = .12 A
repump = 0.00
master = 1.0

dv =     np.array([38.4,36.8])

plt.figure('0repump')
plt.plot(angles,dv,'.-.', label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '0% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
plt.ylim(.85,1.01)
#plt.title('0% Repump Scaled')
plt.legend()

# %% [markdown]
# ### Repump 5%

# %%
#mag field current = .12 A
repump = 0.05
master = 1.0

angles = np.array([0,90])
dv =     np.array([40.8,39.6])


plt.figure('0repump')
plt.plot(angles,dv,'.-.',label = '5% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '5% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 10%

# %%
#mag field current = .12 A
repump = 0.1
master = 1.0

dv =     np.array([43.2,42.4])

plt.figure('0repump')
plt.plot(angles,dv,'.-.', label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('10% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '10% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('10% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()

# %% [markdown]
# ### Repump 15%

# %%
#mag field current = .12 A
repump = 0.15
master = 1.0

angles = np.array([0,90])
dv =     np.array([45.2,44])


plt.figure('0repump')
plt.plot(angles,dv,'.-.',label = '15% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '15% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 20%

# %%
#mag field current = .12 A
repump = 0.20
master = 1.0

dv =     np.array([46,45.6])

plt.figure('0repump')
plt.plot(angles,dv,'.-.', label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
plt.ylabel('Fluorescence (dV)')
plt.savefig('fluorescencehigh2.pdf')
#plt.title('20% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '20% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('20% Repump Scaled')
plt.ylim(.85,1.01)
plt.legend()
plt.savefig('20scaledhigh2.pdf')

# %% [markdown]
# ### Repump 25%

# %%
#mag field current = .12 A
repump = 0.25
master = 1.0

angles = np.array([0,90])
dv =     np.array([46,45.6])


plt.figure('0repump')
plt.plot(angles,dv,'.-.',label = '25% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend()

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '25% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend()

# %% [markdown]
# ### Repump 30%

# %%
#mag field current = .12 A
repump = 0.30
master = 1.0

angles = np.array([0,90])
dv =     np.array([47.2,47.0])


plt.figure('0repump')
plt.plot(angles,dv,'.-.',label = '30% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle')
#plt.title('0% Repumper Repump')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.figure('0repump scaled')
plt.plot(angles,dv/dv[0],'.-.',markersize = 10.0, label = '30% Repumper Pulsed')
plt.grid(True)
plt.xlabel('Angle (degrees)')
plt.ylabel('Fluorescence as Percent of Max')
#plt.title('0% Repumper', fontsize = 18)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.show()
